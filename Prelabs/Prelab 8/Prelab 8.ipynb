# %% [markdown]
# #### ***Your name here***

# %% [markdown]
# # Prelab 8 - Project 2 Proposal
#
#
# In your lab this week, you will write a proposal for the investigation that you plan to complete for Project 2. It will be due on ***Friday at 9am***, and we will discuss it in an appointment during my office hours 10-11am that day.
#
# Below is an excerpt from the Project 2 assignment instructions to help guide you, though I suggest you review the entire assignment document (available [here](https://docs.google.com/document/d/1km7R6j25WvxnFb_bU2YCUELAnA9rByw9pjkKo3dafcw/edit?usp=sharing)) before beginning your proposal
#
# ---
# ***Purpose:***
#
# Utilize your developing statistical and data visualization skills to design and complete a data-driven investigation of exoplanet properties. You will design the “question” that is the focus of your investigation yourself, in consultation with Prof. Follette. Your question should be something interesting to you, but cannot be something that you’ve looked at directly already in a lab or prelab.
#
# ***A good question is:***
#
# 1. Tractable (the data are capable of answering it)
#
# 2. Specific
#
# 3. Substantive (the answer is not intuitively obvious)
#
# ***Constraints/Requirements for Your Investigation:***
#
# You must generate at least two well-designed graphics that are informative in the context of your investigation. This graphics must be well designed and well chosen.
#
# Your investigation must involve at least three columns of data from the table, and must summarize these quantities quantitatively with summary statistics and/or plots.
# Your investigation must involve either (a) a fit to a linear trend, or (b) a quantitative evaluation of a hypothesis, or both.
#
# ---
#
#
# If you haven't already, you should begin with an exploratory investigation of the Exoplanet Database. You are searching for a ***tractable, specific, and substantive*** question that you think the database is capable of answering. For example, in your Lab 6 reports, you investigated the question (Note it's formulated as two questions, but they are related, so it "counts" as one):
#
# *How strongly are planet mass and radius related? Is there more than one relationship evident in the data?*.
#
# Your Prelab 8 Project Proposal should basically be a formulation and justification of two such questions that you think might be suitable for your Project 2 report. I will help you to choose between the two and will give you some guidance on where to find the relevant background information, things to watch out for as you complete your investigation, etc. during our meeting on Friday.
#
# You should use the remainder of this notebook to lay out:
#
# 1) At least two possible questions that you think the database is capable of answering. You need to ***demonstrate*** their feasibility with exploratory or preliminary graphics and statistical calculations.
#
# 2) For each of your two potential questions, you should make a ***data-driven argument*** for why you think the question is sufficiently tractable, specific, and substantive. As always, these should include specific references to the graphics and statistics that informed your choice.
#
# 3) At the end of your prelab, list three questions that you have for me about the nature of the data, how to complete the analyses you propose, etc. These will form the basis of our discussion at our Friday meeting.
#
# The specific requirements are scaffolded below. Make sure to read all of the instructions carefully.

# %%
## read in the dataset here
## REMINDER: Must point to a file in the Shared Google Drive and NOT in your Google Drive

# %% [markdown]
# -------
# ### Exploratory Work
#
# Please complete your exploratory work in a separate notebook and transfer to the space below only what is needed to make the visualizations and statistical calculations that you will use to make a data-driven argument for why your two proposed investigation questions are tractable, specific, and substantive.
#
# In other words, every statistical calcluation or visualization that you put below should be integrated into your description of your proposed questions in the next section.

# %%
#explorations for question 1 (feel free to add more cells)

# %%
#explorations for question 2 (feel free to add more cells)

# %% [markdown]
# ---
# ## Proposed Investigations
#
# Lay out your two proposed questions/investigations here. Each should be phrased as a question (or set of related questions) and you should use your preliminary visualizations and statistics to justify why it is tractable, specific, and substantive.
#
# ### Question 1:
# ***explanation here***
#
# ### Question 2:
# ***explanation here***

# %% [markdown]
# ---
#
# ## Questions
#
# List below three questions that you have for me about the nature of your data, the patterns that you see in it, problems you think might arise, etc.
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
# # Sumbitting Prelabs and Labs for Grading
#
# Before submitting any Google Colab notebook for grading, please follow the following steps
#
# **1) Try running everything in one go (Runtime menu -> Restart and run all)**
#
# Make sure the entire notebook runs from start to finish. If necessary, comment out any un-executable cells from the instructions portion of the lab so the whole notebook will execute in one go.
#
# **2) Restart the kernel (Runtime menu --> Restart Runtime).**
#
# **3) Clear all output (Edit --> clear all outputs).**
#
# **4) Make sure the names of all group members are in a markdown cell at the top of the file and submit the notebook through the Moodle link for this Lab**
