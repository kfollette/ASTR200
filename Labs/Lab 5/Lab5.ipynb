# %% [markdown]
# ***Your Names Here***
#
# # Lab 5 - Comparing Data Subsets with Tabular Data
#
# ## Lab 5 - Contents
# 1. Making Boxplots
# 2. Relating Boxplots to Confidence Intervals
# 3. Computing Confidence Intervals

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sb
import scipy.stats as st

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
# ### Exercise 1: HBCUs
# --------------
# This table tracks the number of physics degrees awarded at Historically Black Colleges and Universities compared to those awarded to Black students at all U.S. institutions.
#
# **a)** Figure out how to read in the HBCUs.tsv table. If it looks weird when you show it in the following cell, try a different function, or visit the docstring for the function you used and use another additional keyword.
#
# **b)** What do you notice from first looking at this table? How many variables are represented and what types of variable are they? Is any information that you would like missing? What questions might these data be able to answer? What might they not be able to answer?
# - For example, it's important to note that, according to the National Center for Education Statistics, HBCUs conferred 13% of the Bachelor's degrees given to Black students in the U.S. in 2017-2018.
#
# **c)** Plot the data from the tablein a single time-series graphic, as you did in the pre-lab. Add appropriate axes labels and a legend. Summarize the result, and what you think it might mean, in a descriptive caption (use a separate markdown cell below your plot for the caption)
#
# **d)** Create a scatter plot directly comparing HBCUs to All Institutions. Summarize the result, and what you think it might mean, in a descriptive caption. Then, describe in 1-2 sentences the ways in which this graphic tells a different story than the one you made in **c** above. Which do you think is more meaningful and why?

# %%
#read in table here
hb =

# %%
#show table here

# %% [markdown]
# ***explanation for b here. make sure to address all of the posed questions***

# %%
#plot for c here

# %% [markdown]
# ***descriptive caption for c here***

# %%
#plot for d here

# %% [markdown]
# ***descriptive caption for d here***

# %% [markdown]
# ***reflection of plots c vs d here***

# %% [markdown]
# ---
# ## 1. Making Boxplots
#
# The syntax for creating a box plot for a pair of pandas dataframe columns is:
#
# ```dataframe.boxplot(column="column name 1", by="column name 2")```
#
# Use of this built-in pandas functionality may be nice for quick exploration, ***HOWEVER*** here again there are other libraries with much more versatile boxplot functionalities. I recommend using the plotting library seaborn and what is called a "notched" boxplot. A schematic that shows you how to intrepret a notched boxplot is below.
#
# ![](https://drive.google.com/uc?export=view&id=15NAUUrhmrPLaY13eKoxdux_IDPyp78XP)
#
# Here is the basic syntax to make a boxplot with seaborn (imported with the shorthand sb in the first cell of this notebook). Note that you will need to turn the pandas dataframe columns that you want into numpy arrays ("var1" and "var2" below), as you did for exercise 1a.
#
# ```sb.boxplot(x=var1,y=var2,notch=True)```
#
# Alternatively, the function can take in multiple categories at once using the
# ```data```
# argument, as in the example below. Notice that the table is indexed so that the years aren't included as a variable.
#
# ```sb.boxplot(data = hb.iloc[:,1:],color='darkseagreen',notch=True)```
#
# ---
# ### Exercise 2
# ---
# **a)** Play around with the inputs to the boxplot function below, as well as the x and y variables until you understand thoroughly what the function shows and what each of the optional and required arguments control. Refer to the docstring as needed. Are the two ways of making a boxplot (provided below) equivalent or different in some way? What do each of their optional and required arguments control?
# **b)** Is the boxplot created in the second cell below of particular interest? Why or why not? Plot the same data as a histogram and describe the similarities and differences between the two plot types.

# %%
#one way. copy or modify this cell
sb.boxplot(x=var1,y=var2,notch=True)

# %%
#another way. copy or modify this cell
sb.boxplot(data = hb.iloc[:,1:],color='darkseagreen',notch=True)
plt.ylabel('Number of Physics Degrees') #notice you can continue to use matplotlib commands on a seaborn plot

# %% [markdown]
# ***part a desciptions here***

# %%
#make a histogram comparing the same populations

# %% [markdown]
# ***explanations of the relative strengths and weaknesses of boxplot vs. histogram for these data below***

# %% [markdown]
# ## 2. Relating Box Plots to Confidence Intervals
#
# ---
# ### Exercise 3
# --------------
#
# **a)** Read in women_stemdegrees.csv. This table from the American Physical Society spans many more years than we've seen in the two previous tables. The version provided, for each subject area, has the number of Bachelor's degrees given to women each year followed by the total number of degrees (all genders). Add a a column for each subject area with the percentage (or fraction) of degrees awarded to women each year. For the remaining exercises, you may decide which column(s) you find most informative or interesting (in terms of subject area and fraction vs. absolute number of degrees granted).
#
# **b)** Plot at least one time-series (comparing at least two categories) and one other scatterplot. Add a descriptive caption describing at least one potential takaway message or question that the data raise.
#
# **c)** Make one boxplot with at least two categories that you deem informative and one that you deem relatively uninformative. Add a descriptive caption describing the differences between the two, your process in creating them, and why you think each is informative/uninformative.
#
# **d)** Now think more broadly. When are boxplots useful and when aren't they? How many and what types of variables are they good at representing? What do they show that other types of plots (e.g. histogram) don't and what don't they show that other types of plots do? What are the shortcomings of boxplots when it comes to representing time-series data (i.e. what scenarios might be misleading)?

# %%
#read in table here

# %%
#show table here

# %%
#add columns here (part a)

# %%
#time series graphic here (part b)

# %% [markdown]
# ***descriptive caption that includes at least one takeaway message for the graphic, or question that it elicits here***

# %%
#boxplot explorations. at least two variables each. 
#play around until you have one informative boxplot and one uninformative one

# %% [markdown]
# ***descriptive caption caomparing the two boxplots (informative and uninformative)***

# %% [markdown]
# ***Reflection on boxplots and their utility (part d)***

# %% [markdown]
# ## 3. Computing Confidence Intervals
#
# ---
# ### Exercise 4
# ---
#
# Now let's do an actual hypothesis test about the meaningfulness of the differences we might visualize with boxplots or histograms using a statistic called the Student's t-test. This test is commonly used to test differences between the means of two samples. Read a little about the test [here](https://en.wikipedia.org/wiki/Student%27s_t-test).
#
# Confidence intervals can be computed using the following basic syntax
#
# ```variable1 = st.t.interval(conf_level,n,loc=np.nanmean(variable2), scale=st.sem(variable2))```
#
# where ```conf_level``` is the confidence level you wish to calculate (e.g. 0.95 is 95% confidence, 0.98 is 98%, etc.)
# ```n``` is the number of samples and should generally be set to the number of valid entries in ```variable2``` minus one.
#
# a) Choose one of the differences that you noted in Exercise 2 to test and formulate it as a null vs. alternative hypothesis apopropriate for a t test. You may also decide to compare different datasets from this pre-lab and lab. For example, has there been an equivalent growth rate across subject areas or demographics? Justify your choice here.
#
# b) The relevant python function is called ttest_ind in the scipy stats library (imported as st above). An example is shown below, using the HBCU dataset. Interpret the output of the function in a single sentence. What does it mean? Explain why the pvalue is so low by referring back to the boxplot example.
#
# c) Run the test for your hypothesis. What did you find? What do the numbers tell you?

# %%
st.t.interval(0.95,len(hb['HBCUs'])-1,loc=np.nanmean(hb['HBCUs']), scale=st.sem(hb['HBCUs']))

# %%
#example using HBCUs vs. all institutions
st.ttest_ind(hb['HBCUs'],hb['All Institutions'])

# %% [markdown]
# ---
# ### Exercise 5: Final Plot and Take-Aways
# --------------
# Use a result you already found in this lab or keep exploring the data until you have creted a plot that you think tells a particularly meaningful and coherent story about the populations described by the data. You may use any of the three datasets introduced in the Prelab or Lab for this week.
#
# You will present this plot to your classmates at the end of the lab session.
#
# Requirements are:
# 1) Your plot should compare at least two populations/samples.
# 2) Your plot and/or caption should clearly demonstrate the statistical significance (confidence) of any differences between the populations.
# 3) Your plot should include a descriptive caption that explains the nature of the data, the takeaway message of the graphic, and any caveats (sources of error, missing information).
#
# *In whatever time remains before we reconvene to show plots*
# You and your partner should practice presenting the graphic. You should both plan to speak about some aspect of it. The "presentation" should take approximately 2min.
#
# If more time remains, address the following question in the space provided below. What additional questions did this analysis raise for you that you would explore given more time? How would you go about doing this?

# %%
#plotting code here

# %% [markdown]
# ***Your caption here***

# %% [markdown]
# ***Your explanation here (if time permits)***

# %% [markdown]
# ---
# # Sumbitting Prelabs and Labs for Grading
#
# Before submitting any Google Colab notebook for grading, please follow the following steps
#
# **1) Try running everything in one go (Runtime menu -> Restart and run all)**
#
# Make sure the entire notebook runs from start to finish. If necessary, comment out any un-executable cells from the instructions portion of the lab so the whole notebook will execute in one go.
#
# **2) Restart the kernel (Runtime menu --> Restart Runtime).**
#
# **3) Clear all output (Edit --> clear all outputs).**
#
# **4) Make sure the names of all group members are in a markdown cell at the top of the file and submit the notebook through the Moodle link for this Lab**
