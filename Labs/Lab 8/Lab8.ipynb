# %% [markdown]
# ### ***Your Name(s) Here***

# %%
#the usual
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sbn
# %matplotlib inline

# %%
##Hubble's Data!
dists = np.array([0.032,0.034,0.214,0.263,0.275,0.275,0.45,0.5,0.5,0.63,0.8,0.9,0.9,
         0.9,0.9,1.0,1.1,1.1,1.4,1.7,2.0,2.0,2.0,2.0])#Mpc
vels = np.array([170.,290,-130,-70,-185,-220,200,290,270,200,300,-30,650,150,500,920,450,500,500,960,500,850,800,1000]) #km/sec

# %% [markdown]
# # Lab 8 - Hubble's Law Monte Carlo Simulation Exercise
#
# This exercise uses the Monte Carlo simulation, multipanel plotting, covariance matrix, model fitting, and random sampling ideas from your last several labs and prelabs to investigate the question:
#
# ***How much of the variation in Hubble's original data might have been due to random variation and a relatively small sample size?***
#
# This will allow you to place some bounds on how well Hubble's original relation was able to constrain the slope of "Hubble's Law", which is used to constrain important quantities like the expansion rate and age of the universe.
#
# *Recall that, as you established in Lab 4, Hubble's original data contained a large systematic error in the distances to these galaxies (all substantially underestimated, though accurate relative to one another). You can also attempt this exercise with the modern data for Hubble's 24 galaxy sample, which you assembled as part of Prelab 4*
#
# ### Instructions for your Investigation
#
# ***Read all steps carefully and make sure you include all required elements in your final writeup***
#
# The steps that you should follow in your investigation today are:
#
# 1. Use the numpy.random.multivariate_normal function to create a bivariate normal distribution with the same properties as Hubble's original data. You will have to read the help function to figure out what input to give it, and I highly suggest that you write a few tests and make sure your output makes sense before moving on.
#
# >*Hint: you will need some summary statistics from the original data, plus a covariance matrix to create this distribution*.
#
# 2. Create a multipanel 2x4 grid of plots (see Prelab 7 for help with setting up multipanel plots), each of which should be a scatter plot with 24 points (as in Hubble's original data) randomly drawn from the distribution you established in (1).
# 3. Fit a line to the data in each plot and include the correlation coefficient and slope (also known as the hubble constant, make sure to include units) in the legend of each subpanel. Think carefully about which of the correlation coefficients you investigated in Lab 6 is most appropriate for this dataset. Make sure to justify your choice in your final writeup.
# 4. Now write a function that will draw an arbitrary number (n) of random 24 point realizations from the distribution and return an array of the best fit slopes and correlation coefficients.  In other words, write a simulation that will (a) do this same process of randomly drawing and fitting 24 data points an arbitrarily large  number of times (n) and (b) assemble a list (a sampling distribution!) of the best fit slopes and correlation coefficients.
# 5. Create overlapping histograms or boxplots that compare the sampling distributions returned by your function for different numbers of random realizations/draws (different n values). Note any changes in the distribution with the number of total realizations and make an argument for how many you think you "need" to answer the question in your final writeup.
# 6. Use your sampling distributions and visualizations of them to design and complete a hypothesis test. There are many possibilities - start by formulating a "null hypothesis". Ask if you want help/guidance.
# 7. At the bottom of this notebook, write a 3-5 paragraph summary describing the results of this investigation, including: methods, findings, and conclusions. Make explicit connections to as many ideas from this unit as you can, and include specific references to the plots that you designed following the instructions above. Justify any choices that you made (e.g. choice of correlation coefficient, number of random realizations). End with a paragraph describing how you think this kind of simulation might be useful generally (e.g. what types of questions might you be able to answer with this or a similar technique)?

# %%
# your work here. you will want to insert many more cells.

# %% [markdown]
# ***Your 3-5 paragraph data-driven argument here***

# %% [markdown]
# ---
# # Sumbitting Prelabs and Labs for Grading
#
# Before submitting any Google Colab notebook for grading, please follow the following steps
#
# **1) Try running everything in one go (Runtime menu -> Restart and run all)**
#
# Make sure the entire notebook runs from start to finish. If necessary, comment out any un-executable cells from the instructions portion of the lab so the whole notebook will execute in one go.
#
# **2) Restart the kernel (Runtime menu --> Restart Runtime).**
#
# **3) Clear all output (Edit --> clear all outputs).**
#
# **4) Make sure the names of all group members are in a markdown cell at the top of the file and submit the notebook through the Moodle link for this Lab**
